# %%
# imports
import pandas as pd
from pandas.api.types import is_numeric_dtype
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import grangercausalitytests
from sklearn.impute import KNNImputer
import warnings
warnings.filterwarnings("ignore")

# %%
def load_data(file_path):
    """
    Load data from a CSV file.
    
    Parameters:
    - file_path: str, path to the CSV file.
    
    Returns:
    - pandas DataFrame, the loaded data.
    """
    return pd.read_csv(file_path)
    
def check_is_numeric(data):
    """
    Checks if the columns are numeric.

    Parameters:
    - data : pandas dataframe
    
    Returns:
    Boolean variable(True/ False) and prints the non-numeric columns.
    """
    flag=0
    non_numeric_cols=[]
    for column in data.columns:
        if(is_numeric_dtype(data[column])==False):
            flag+=1
            non_numeric_cols.append(column)
    if(flag!=0):
        print(f'Please Provide Numeric Data.\nNon-numeric Attributes are- {non_numeric_cols}')
        return False
    else:
        return True
        
def granger_causality_test(data, max_lag):
    """
    Perform Granger causality test.
    
    Parameters:
    - data: pandas DataFrame, the data containing the time series.
    - max_lag: int, the maximum lag to be tested.
    
    Returns:
    - test_result: dict, the results of the Granger causality test.
    """
    return grangercausalitytests(data, max_lag, verbose=True)

def plot_time_series(data, lag):
    """
    Plot the two time series with a specified lag.
    
    Parameters:
    - data: pandas DataFrame, the data containing the time series.
    - lag: int, the lag to apply.
    """
    plt.figure(figsize=(12, 6))
    plt.plot(data['time'], data['x'], label='Series X')
    plt.plot(data['time'], data['y'].shift(lag), label=f'Series Y (shifted by {lag} lags)')
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title(f'Time Series with Lag {lag}')
    plt.grid(True)
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Driver code for user to run

# %%
def main():
    try:
        # Prompt user for file paths and lag value
        # file_path_1 = input("Enter the path for the first time series CSV file: ")
        # file_path_2 = input("Enter the path for the second time series CSV file: ")
        file_path_1 = r"D:\Stelco\Work\Dynamic Correlation\time_series_x.csv"
        file_path_2 = r"D:\Stelco\Work\Dynamic Correlation\time_series_y.csv"
        max_lag = int(input("Enter the maximum lag value to test: "))
        
        # Load data
        data1 = load_data(file_path_1)
        data2 = load_data(file_path_2)
        
        if(len(data1.columns)!=2 or len(data2.columns)!=2):
            print('Test requires exactly 2 columns - time and values for both datasets!')
            return
        
        # Assuming the time series are in columns named 'value' in both files
        # Rename columns to unify
        data1.rename(columns={data1.columns[0]: 'time', data1.columns[1]: 'x'}, inplace=True)
        data2.rename(columns={data2.columns[0]: 'time', data2.columns[1]: 'y'}, inplace=True)
    
        # Check if both have the same time intervals and same duration
        if (data1.time.equals(data2.time))==False:
            print('Values in the Time columns are different in both datasets.\nTest can not be performed')
            return
    
        # Merge the two dataframes on 'time'
        merged_data = pd.merge(data1, data2, on='time')
    
        # Checking for numeric data
        if(check_is_numeric(merged_data)==False):
            return
            
        # Handling missing values (if any)
        imputer = KNNImputer(n_neighbors=8)
        merged_data = pd.DataFrame(imputer.fit_transform(merged_data), columns=merged_data.columns)
        
        # Perform Granger causality test
        test_result = granger_causality_test(merged_data[['x', 'y']], max_lag)
    
        # Extract and print p-values, and find the lag with the smallest p-value
        best_lag = None
        best_p_value = float('inf')
        print("\nGranger Causality Test Results:")
        for key in test_result:
            f_test_p_value = test_result[key][0]['ssr_ftest'][1]
            print(f'Lag {key}: p-value = {f_test_p_value}')
            if f_test_p_value < best_p_value:
                best_p_value = f_test_p_value
                best_lag = key

        # Plot the series with the best lag
        if best_lag is not None:
            print(f"\nBest lag based on p-value: {best_lag}")
            plot_time_series(merged_data, best_lag)
        else:
            print("No significant Granger causality found.")
            
    except Exception as e:
        print(e)
if __name__ == "__main__":
    main()


# Usage Example:
# Enter the path for the first time series CSV file: time_series_x.csv
# Enter the path for the second time series CSV file: time_series_y.csv
# Enter the maximum lag value to test: 20
# Out:
# Enter the maximum lag value to test:  20
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=17.9490 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=18.2237 , p=0.0000  , df=1
# likelihood ratio test: chi2=17.4370 , p=0.0000  , df=1
# parameter F test:         F=17.9490 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=16.1500 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=33.1368 , p=0.0000  , df=2
# likelihood ratio test: chi2=30.6390 , p=0.0000  , df=2
# parameter F test:         F=16.1500 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=17.2504 , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=53.6577 , p=0.0000  , df=3
# likelihood ratio test: chi2=47.4543 , p=0.0000  , df=3
# parameter F test:         F=17.2504 , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=12.5945 , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=52.8027 , p=0.0000  , df=4
# likelihood ratio test: chi2=46.7550 , p=0.0000  , df=4
# parameter F test:         F=12.5945 , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=10.2464 , p=0.0000  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=54.2948 , p=0.0000  , df=5
# likelihood ratio test: chi2=47.8991 , p=0.0000  , df=5
# parameter F test:         F=10.2464 , p=0.0000  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=7.1157  , p=0.0000  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=45.7604 , p=0.0000  , df=6
# likelihood ratio test: chi2=41.0857 , p=0.0000  , df=6
# parameter F test:         F=7.1157  , p=0.0000  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=5.7153  , p=0.0000  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=43.3786 , p=0.0000  , df=7
# likelihood ratio test: chi2=39.1297 , p=0.0000  , df=7
# parameter F test:         F=5.7153  , p=0.0000  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.3630  , p=0.0001  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=38.2950 , p=0.0000  , df=8
# likelihood ratio test: chi2=34.9182 , p=0.0000  , df=8
# parameter F test:         F=4.3630  , p=0.0001  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.6041  , p=0.0004  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=36.0204 , p=0.0000  , df=9
# likelihood ratio test: chi2=32.9984 , p=0.0001  , df=9
# parameter F test:         F=3.6041  , p=0.0004  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.9707  , p=0.0018  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=33.3987 , p=0.0002  , df=10
# likelihood ratio test: chi2=30.7675 , p=0.0006  , df=10
# parameter F test:         F=2.9707  , p=0.0018  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.1747  , p=0.0180  , df_denom=166, df_num=11
# ssr based chi2 test:   chi2=27.2358 , p=0.0042  , df=11
# likelihood ratio test: chi2=25.4437 , p=0.0078  , df=11
# parameter F test:         F=2.1747  , p=0.0180  , df_denom=166, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.6550  , p=0.0814  , df_denom=163, df_num=12
# ssr based chi2 test:   chi2=22.9061 , p=0.0285  , df=12
# likelihood ratio test: chi2=21.6146 , p=0.0421  , df=12
# parameter F test:         F=1.6550  , p=0.0814  , df_denom=163, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.6231  , p=0.0837  , df_denom=160, df_num=13
# ssr based chi2 test:   chi2=24.6609 , p=0.0256  , df=13
# likelihood ratio test: chi2=23.1649 , p=0.0397  , df=13
# parameter F test:         F=1.6231  , p=0.0837  , df_denom=160, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.2214  , p=0.2648  , df_denom=157, df_num=14
# ssr based chi2 test:   chi2=20.2577 , p=0.1222  , df=14
# likelihood ratio test: chi2=19.2287 , p=0.1564  , df=14
# parameter F test:         F=1.2214  , p=0.2648  , df_denom=157, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.0907  , p=0.3693  , df_denom=154, df_num=15
# ssr based chi2 test:   chi2=19.6542 , p=0.1856  , df=15
# likelihood ratio test: chi2=18.6787 , p=0.2287  , df=15
# parameter F test:         F=1.0907  , p=0.3693  , df_denom=154, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.0064  , p=0.4532  , df_denom=151, df_num=16
# ssr based chi2 test:   chi2=19.6208 , p=0.2378  , df=16
# likelihood ratio test: chi2=18.6436 , p=0.2876  , df=16
# parameter F test:         F=1.0064  , p=0.4532  , df_denom=151, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.1774  , p=0.2896  , df_denom=148, df_num=17
# ssr based chi2 test:   chi2=24.7487 , p=0.1005  , df=17
# likelihood ratio test: chi2=23.2123 , p=0.1425  , df=17
# parameter F test:         F=1.1774  , p=0.2896  , df_denom=148, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.4488  , p=0.1176  , df_denom=145, df_num=18
# ssr based chi2 test:   chi2=32.7329 , p=0.0180  , df=18
# likelihood ratio test: chi2=30.1007 , p=0.0365  , df=18
# parameter F test:         F=1.4488  , p=0.1176  , df_denom=145, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.3913  , p=0.1401  , df_denom=142, df_num=19
# ssr based chi2 test:   chi2=33.6941 , p=0.0200  , df=19
# likelihood ratio test: chi2=30.8998 , p=0.0414  , df=19
# parameter F test:         F=1.3913  , p=0.1401  , df_denom=142, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.4249  , p=0.1203  , df_denom=139, df_num=20
# ssr based chi2 test:   chi2=36.9049 , p=0.0120  , df=20
# likelihood ratio test: chi2=33.5704 , p=0.0292  , df=20
# parameter F test:         F=1.4249  , p=0.1203  , df_denom=139, df_num=20
#
# Granger Causality Test Results:
# Lag 1: p-value = 3.489433491978467e-05
# Lag 2: p-value = 3.2721369908376653e-07
# Lag 3: p-value = 5.997430395624752e-10
# Lag 4: p-value = 4.289939717783517e-09
# Lag 5: p-value = 1.1178357310106629e-08
# Lag 6: p-value = 8.022794400828778e-07
# Lag 7: p-value = 5.621274080551035e-06
# Lag 8: p-value = 8.023625830040602e-05
# Lag 9: p-value = 0.00038868605105857264
# Lag 10: p-value = 0.0018038445728201697
# Lag 11: p-value = 0.018007977791236193
# Lag 12: p-value = 0.08141479831453478
# Lag 13: p-value = 0.08366084612201447
# Lag 14: p-value = 0.2647775211900979
# Lag 15: p-value = 0.36929758428476045
# Lag 16: p-value = 0.453208882345506
# Lag 17: p-value = 0.28962860814206065
# Lag 18: p-value = 0.11761204448362422
# Lag 19: p-value = 0.1400805048830533
# Lag 20: p-value = 0.12034806907585247
#
# Best lag based on p-value: 3
