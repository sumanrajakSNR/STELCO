# %%
import pandas as pd
import os

# Path to master CSV and folder of per-coil CSVs
master_csv = "combined_good_coil_data_filtered_added gauge target and phases_Gauge lst 0.08.csv"
coil_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Whole_Phase_Good_Clustered"

# Load master file
master_df = pd.read_csv(master_csv)

# Extract unique coil IDs from master
coil_ids = master_df['Coil ID'].unique()

# Create dictionary for std4 id lookup
std4_dict = {}

# Loop through coil IDs and fetch std4 id
for coil_id in coil_ids:
    coil_file = os.path.join(coil_folder, f'{coil_id}.csv')
    if os.path.exists(coil_file):
        coil_df = pd.read_csv(coil_file)
        # Assuming 'std4 id' column exists in coil CSV
        std4_value = coil_df['STD4_ID'].iloc[0]
        std4_dict[coil_id] = std4_value

# Map std4 id to master dataframe
master_df['STD4_ID'] = master_df['Coil ID'].map(std4_dict)

# Save updated master file
master_df.to_csv("combined_good_coil_data_filtered_added gauge target and phases_Gauge lst 0.08_std4.csv", index=False)

# %%
# Out:
# ✅ Merged successfully with additional columns: ['STD4_ID', 'rollingmode', 'CM_WIDTH', 'Grade']
