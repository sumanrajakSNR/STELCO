# %%
import pandas as pd
import os

# %%
sample_interval = 3

# %%
def assign_phase_column_by_coil(df, coil_col, ramp_col):
    def assign_phase(group):
        if group[ramp_col].max() <= 15:
            group['Phase'] = None
            return group
        norm_val = group[ramp_col].mode()[0]
        norm_df = group[group[ramp_col] == norm_val]
        if norm_df.empty:
            group['Phase'] = None
            return group
        phase1_end = norm_df.index[0]
        phase2_end = norm_df.index[-1]
        group['Phase'] = None
        group.loc[:phase1_end, 'Phase'] = 'Phase 1'
        group.loc[phase1_end:phase2_end, 'Phase'] = 'Phase 2'
        group.loc[phase2_end+1:, 'Phase'] = 'Phase 3'
        return group

    return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)

# Load your CSV file
# df = pd.read_csv(f"bad_and_bad_coils_{sample_interval}_feet_sampling_combined_added_gauge_target.csv")
df = pd.read_csv("combined_good_coil_data_filtered_added gauge target.csv")

# Apply the function with the coil column name (replace 'CoilID' with your actual coil column)
df_binning = assign_phase_column_by_coil(df, coil_col='Coil ID', ramp_col='Master Ramp')

# output_csv = f"bad_and_bad_coils_{sample_interval}_feet_sampling_combined_added_gauge_target_phase_division.csv"
output_csv = "combined_good_coil_data_filtered_added gauge target and phases.csv"

# Clear the output file if exists
if os.path.exists(output_csv):
    os.remove(output_csv)

# Save the resulting DataFrame with phase column
df_binning.to_csv(output_csv, index=False)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_20800\2101915427.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)

# %%
import pandas as pd
import os

# Assign phase function you provided
def assign_phase_column_by_coil(df, coil_col, ramp_col):
    def assign_phase(group):
        if group[ramp_col].max() <= 15:
            group['Phase'] = None
            return group
        norm_val = group[ramp_col].mode()[0]
        norm_df = group[group[ramp_col] == norm_val]
        if norm_df.empty:
            group['Phase'] = None
            return group
        phase1_end = norm_df.index[0]
        phase2_end = norm_df.index[-1]
        group['Phase'] = None
        group.loc[:phase1_end, 'Phase'] = 'Phase 1'
        group.loc[phase1_end:phase2_end, 'Phase'] = 'Phase 2'
        group.loc[phase2_end+1:, 'Phase'] = 'Phase 3'
        return group

    return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)

# Paths
merged_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Whole_Phase_Good_Merged"
phase_output_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Whole_Phase_Good_Phased"

# Ensure output folder exists
os.makedirs(phase_output_folder, exist_ok=True)

# Process each merged CSV for phase assignment
for filename in os.listdir(merged_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(merged_folder, filename)
        df = pd.read_csv(file_path)
        
        # Apply phase assignment, use column names as per your data: 'Coil ID' and 'Master Ramp'
        df_with_phase = assign_phase_column_by_coil(df, coil_col='Coil ID', ramp_col='Master Ramp')
        
        # Save updated file to new folder
        save_path = os.path.join(phase_output_folder, filename)
        df_with_phase.to_csv(save_path, index=False)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# ...
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_12696\1945719481.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(coil_col).apply(assign_phase).reset_index(drop=True)
