# %% [markdown]
# ## Merging

# %%
import os
import pandas as pd
import random
import gc  # for garbage collection

master_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Master Whole Phase"
phase_folder = r"D:\Stelco\Work\Dynamic Correlation\All coils remaining columns\Whole Phase"
output_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Merged whole Phase"

os.makedirs(output_folder, exist_ok=True)

file_names = os.listdir(master_folder)
csv_files = [f for f in file_names if f.endswith('.csv')]

for filename in csv_files:
    master_path = os.path.join(master_folder, filename)
    phase_path = os.path.join(phase_folder, filename)
    
    if not os.path.exists(phase_path):
        print(f"Warning: {phase_path} does not exist. Skipping.")
        continue
        
    df_master = pd.read_csv(master_path)
    df_phase = pd.read_csv(phase_path)
    
    df_merged = pd.merge(df_master, df_phase, on='Coil ID', how='left')
    
    output_path = os.path.join(output_folder, filename)
    df_merged.to_csv(output_path, index=False)

# %% [markdown]
# ## Merging in Chunks

# %%
import os
import pandas as pd
import gc

master_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Master Whole Phase"
phase_folder = r"D:\Stelco\Work\Dynamic Correlation\All coils remaining columns\Whole Phase"
output_folder = r"F:\Merged Whole Phase"

os.makedirs(output_folder, exist_ok=True)
file_names = os.listdir(master_folder)
csv_files = [f for f in file_names if f.endswith('.csv')]

chunk_size = 50000  # Adjust based on your memory constraints

merge_keys = ['Coil ID', 'Time', 'Master Ramp', 'Coil Length [30ms]']

# Columns to keep from master file
master_columns_keep = [
    'Coil ID', 'Time', 'Master Ramp', 'Coil Length [30ms]','X4 Gauge Deviation', 'Stand 1 Gap Operator Offset', 'Stand 2 Gap Operator Offset',
    'Stand 3 Gap Operator Offset', 'Stand 4 Gap Operator Offset', 'S1 Operating Bending Trim', 'S2 Operating Bending Trim',
    'S3 Operating Bending Trim', 'S4 Operating Bending Trim',
    'X0 Gauge Deviation', 'X1 Gauge Deviation',
    'Stand 1-2 Tension Reference', 'Stand 2-3 Tension Reference', 'Stand 3-4 Tension Reference', 'Stand 1-2 Total Tension Feedback',
    'Stand 2-3 Total Tension Feedback', 'Stand 3-4 Total Tension Feedback', 'Exit Tension Reel Tension Reference',
    'Tension Reel Calculated Tension', 'Stand 1 Gap Bite Offset', 'Stand 1 Gap Stick Offset', 'Stand 1 Gap Thread Offset',
    'Stand 1 Thread Gap Setpoint', 'Stand 1 Run Gap Setpoint', 'Stand 2 Gap Bite Offset', 'Stand 2 Gap Stick Offset',
    'Stand 2 Gap Thread Offset', 'Stand 2 Thread Gap Setpoint', 'Stand 2 Run Gap Setpoint', 'Stand 3 Gap Bite Offset',
    'Stand 3 Gap Stick Offset', 'Stand 3 Gap Thread Offset', 'Stand 3 Thread Gap Setpoint', 'Stand 3 Run Gap Setpoint',
    'Stand 4 Gap Bite Offset', 'Stand 4 Gap Stick Offset', 'Stand 4 Gap Thread Offset', 'Stand 4 Thread Gap Setpoint',
    'Stand 4 Run Gap Setpoint', 'Stand 1 Predicted Run Force', 'Stand 2 Predicted Run Force', 'Stand 3 Predicted Run Force',
    'Stand 4 Predicted Run Force', 'Stand 1 - Total Force', 'Stand 2 - Total Force', 'Stand 2 - Total Force', 'Stand 2 - Total Force',
    'Stand 1 Top Current Feedback', 'Stand 2 Top Current Feedback', 'Stand 3 Top Current Feedback', 'Stand 4 Top Current Feedback',
    'Stand 1 Bottom Current Feedback', 'Stand 2 Bottom Current Feedback', 'Stand 3 Bottom Current Feedback', 'Stand 4 Bottom Current Feedback',
    'AGC GE Feedforward Hardness Number', 'AGC Alex Dynamic Feedforward Hardness Number', 'Stand 1 Total Bending Feedback',
    'Stand 2 Total Bending Feedback', 'Stand 3 Total Bending Feedback', 'Stand 4 OS Total Bending Feedback', 'Stand 4 DS Total Bending Feedback', 'Stand 1 - Operator Side Force',
    'Stand 1 - Drive Side Force', 'Stand 2 - Operator Side Force', 'Stand 2 - Drive Side Force', 'Stand 3 - Operator Side Force',  'Stand 3 - Drive Side Force',
    'Stand 4 - Operator Side Force', 'Stand 4 - Drive Side Force', 'Stand 1-2 Total Tension Feedback', 'Stand 2-3 Total Tension Feedback', 'Stand 3-4 Total Tension Feedback',
    'Stand 1 Drive Speed Feedback', 'Stand 2 Drive Speed Feedback', 'Stand 3 Drive Speed Feedback', 'Stand 4 Drive Speed Feedback',
    'Neet Oil Concentration', 'Stand 1-3 Solution Temperature', 'Stand 1-3 Solution System Pressure',
    'Stand 4 Solution System Pressure', 'Stand 1 Gap Eccentricity Trim', 'Stand 2 Gap Eccentricity Trim',
    'Stand 3 Gap Eccentricity Trim', 'Stand 4 Gap Eccentricity Trim', 'Morgoil OperBottom Bearing Outflow Temp Stand1',
    'Morgoil OperTop Bearing Outflow Temp Stand1', 'Morgoil DriveBottom Bearing Outflow Temp Stand1',
    'Morgoil DriveTop Bearing Outflow Temp Stand1', 'Morgoil OperBottom Bearing Outflow Temp Stand2',
    'Morgoil OperTop Bearing Outflow Temp Stand2', 'Morgoil DriveBottom Bearing Outflow Temp Stand2',
    'Morgoil DriveTop Bearing Outflow Temp Stand2', 'Morgoil OperBottom Bearing Outflow Temp Stand3',
    'Morgoil OperTop Bearing Outflow Temp Stand3', 'Morgoil DriveBottom Bearing Outflow Temp Stand3',
    'Morgoil DriveTop Bearing Outflow Temp Stand3', 'Morgoil OperBottom Bearing Outflow Temp Stand4',
    'Morgoil OperTop Bearing Outflow Temp Stand4', 'Morgoil DriveBottom Bearing Outflow Temp Stand4',
    'Morgoil DriveTop Bearing Outflow Temp Stand4'
]

total_files = len(csv_files)

for file_index, filename in enumerate(csv_files, start=1):
    print(f"\nProcessing file {file_index} of {total_files}: {filename}")

    master_path = os.path.join(master_folder, filename)
    phase_path = os.path.join(phase_folder, filename)

    if not os.path.exists(phase_path):
        print(f"  Warning: {phase_path} does not exist. Skipping.")
        continue

    print("  Reading phase file...")
    df_phase = pd.read_csv(phase_path)
    print(f"  Phase file loaded. Shape: {df_phase.shape}")

    output_path = os.path.join(output_folder, filename)
    first_chunk = True
    chunk_number = 1
    total_rows_written = 0

    for master_chunk in pd.read_csv(master_path, chunksize=chunk_size):
        print(f"    Processing chunk {chunk_number}, shape before selection: {master_chunk.shape}")

        # Keep only required columns, plus the merge keys if not already included
        # To ensure merge keys are present, add them to the list if missing
        for key in merge_keys:
            if key not in master_columns_keep:
                master_columns_keep.append(key)
        master_chunk = master_chunk[master_columns_keep]

        print(f"    Shape after keeping specified columns: {master_chunk.shape}")

        # Merge on the multiple keys
        df_merged = pd.merge(master_chunk, df_phase, on=merge_keys, how='left')
        print(f"    Merged chunk shape: {df_merged.shape}")

        df_merged.to_csv(output_path, mode='w' if first_chunk else 'a', header=first_chunk, index=False)
        total_rows_written += df_merged.shape[0]

        print(f"    Written {df_merged.shape[0]} merged rows to disk. Cumulative total: {total_rows_written}")

        first_chunk = False
        chunk_number += 1

        del master_chunk, df_merged
        gc.collect()

    del df_phase
    gc.collect()

    print(f"Finished processing file {file_index} of {total_files}: {filename}, total rows written: {total_rows_written}")

print("All files processed!")
# Out:
# Processing file 1 of 2988: 5386400.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7458, 138)
#     Processing chunk 1, shape before selection: (7458, 731)
#     Shape after keeping specified columns: (7458, 105)
#     Merged chunk shape: (7458, 239)
#     Written 7458 merged rows to disk. Cumulative total: 7458
# Finished processing file 1 of 2988: 5386400.csv, total rows written: 7458
#
# Processing file 2 of 2988: 5386566.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4136, 138)
#     Processing chunk 1, shape before selection: (4136, 731)
#     Shape after keeping specified columns: (4136, 105)
#     Merged chunk shape: (4136, 239)
#     Written 4136 merged rows to disk. Cumulative total: 4136
# Finished processing file 2 of 2988: 5386566.csv, total rows written: 4136
#
# Processing file 3 of 2988: 5422529.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6668, 138)
#     Processing chunk 1, shape before selection: (6668, 731)
#     Shape after keeping specified columns: (6668, 105)
#     Merged chunk shape: (6668, 239)
#     Written 6668 merged rows to disk. Cumulative total: 6668
# Finished processing file 3 of 2988: 5422529.csv, total rows written: 6668
#
# Processing file 4 of 2988: 5427072.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5249, 138)
#     Processing chunk 1, shape before selection: (5249, 731)
#     Shape after keeping specified columns: (5249, 105)
#     Merged chunk shape: (5249, 239)
#     Written 5249 merged rows to disk. Cumulative total: 5249
# Finished processing file 4 of 2988: 5427072.csv, total rows written: 5249
#
# Processing file 5 of 2988: 5431675.csv
#   Reading phase file...
#   Phase file loaded. Shape: (11071, 138)
#     Processing chunk 1, shape before selection: (11071, 731)
#     Shape after keeping specified columns: (11071, 105)
#     Merged chunk shape: (11071, 239)
#     Written 11071 merged rows to disk. Cumulative total: 11071
# Finished processing file 5 of 2988: 5431675.csv, total rows written: 11071
#
# Processing file 6 of 2988: 5431710.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3903, 138)
#     Processing chunk 1, shape before selection: (3903, 731)
#     Shape after keeping specified columns: (3903, 105)
#     Merged chunk shape: (3903, 239)
#     Written 3903 merged rows to disk. Cumulative total: 3903
# Finished processing file 6 of 2988: 5431710.csv, total rows written: 3903
#
# Processing file 7 of 2988: 5431882.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4972, 138)
#     Processing chunk 1, shape before selection: (4972, 731)
#     Shape after keeping specified columns: (4972, 105)
#     Merged chunk shape: (4972, 239)
#     Written 4972 merged rows to disk. Cumulative total: 4972
# Finished processing file 7 of 2988: 5431882.csv, total rows written: 4972
#
# Processing file 8 of 2988: 5431937.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2915, 138)
#     Processing chunk 1, shape before selection: (2915, 731)
#     Shape after keeping specified columns: (2915, 105)
#     Merged chunk shape: (2915, 239)
#     Written 2915 merged rows to disk. Cumulative total: 2915
# Finished processing file 8 of 2988: 5431937.csv, total rows written: 2915
#
# Processing file 9 of 2988: 5431942.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2899, 138)
#     Processing chunk 1, shape before selection: (2899, 731)
#     Shape after keeping specified columns: (2899, 105)
#     Merged chunk shape: (2899, 239)
#     Written 2899 merged rows to disk. Cumulative total: 2899
# Finished processing file 9 of 2988: 5431942.csv, total rows written: 2899
#
# Processing file 10 of 2988: 5431945.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2962, 138)
#     Processing chunk 1, shape before selection: (2962, 731)
#     Shape after keeping specified columns: (2962, 105)
#     Merged chunk shape: (2962, 239)
#     Written 2962 merged rows to disk. Cumulative total: 2962
# Finished processing file 10 of 2988: 5431945.csv, total rows written: 2962
#
# Processing file 11 of 2988: 5431949.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2720, 138)
#     Processing chunk 1, shape before selection: (2720, 731)
#     Shape after keeping specified columns: (2720, 105)
#     Merged chunk shape: (2720, 239)
#     Written 2720 merged rows to disk. Cumulative total: 2720
# Finished processing file 11 of 2988: 5431949.csv, total rows written: 2720
#
# Processing file 12 of 2988: 5431954.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3298, 138)
#     Processing chunk 1, shape before selection: (3298, 731)
#     Shape after keeping specified columns: (3298, 105)
#     Merged chunk shape: (3298, 239)
#     Written 3298 merged rows to disk. Cumulative total: 3298
# Finished processing file 12 of 2988: 5431954.csv, total rows written: 3298
#
# Processing file 13 of 2988: 5431958.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2958, 138)
#     Processing chunk 1, shape before selection: (2958, 731)
#     Shape after keeping specified columns: (2958, 105)
#     Merged chunk shape: (2958, 239)
#     Written 2958 merged rows to disk. Cumulative total: 2958
# Finished processing file 13 of 2988: 5431958.csv, total rows written: 2958
#
# Processing file 14 of 2988: 5431962.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2938, 138)
#     Processing chunk 1, shape before selection: (2938, 731)
#     Shape after keeping specified columns: (2938, 105)
#     Merged chunk shape: (2938, 239)
#     Written 2938 merged rows to disk. Cumulative total: 2938
# Finished processing file 14 of 2988: 5431962.csv, total rows written: 2938
#
# Processing file 15 of 2988: 5431982.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3280, 138)
#     Processing chunk 1, shape before selection: (3280, 731)
#     Shape after keeping specified columns: (3280, 105)
#     Merged chunk shape: (3280, 239)
#     Written 3280 merged rows to disk. Cumulative total: 3280
# Finished processing file 15 of 2988: 5431982.csv, total rows written: 3280
#
# Processing file 16 of 2988: 5432044.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7719, 138)
#     Processing chunk 1, shape before selection: (7719, 731)
#     Shape after keeping specified columns: (7719, 105)
#     Merged chunk shape: (7719, 239)
#     Written 7719 merged rows to disk. Cumulative total: 7719
# Finished processing file 16 of 2988: 5432044.csv, total rows written: 7719
#
# Processing file 17 of 2988: 5432153.csv
#   Reading phase file...
#   Phase file loaded. Shape: (87, 138)
#     Processing chunk 1, shape before selection: (87, 731)
#     Shape after keeping specified columns: (87, 105)
#     Merged chunk shape: (87, 239)
#     Written 87 merged rows to disk. Cumulative total: 87
# Finished processing file 17 of 2988: 5432153.csv, total rows written: 87
#
# Processing file 18 of 2988: 5432334.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3541, 138)
#     Processing chunk 1, shape before selection: (3541, 731)
#     Shape after keeping specified columns: (3541, 105)
#     Merged chunk shape: (3541, 239)
#     Written 3541 merged rows to disk. Cumulative total: 3541
# Finished processing file 18 of 2988: 5432334.csv, total rows written: 3541
#
# Processing file 19 of 2988: 5432378.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3431, 138)
#     Processing chunk 1, shape before selection: (3431, 731)
#     Shape after keeping specified columns: (3431, 105)
#     Merged chunk shape: (3431, 239)
#     Written 3431 merged rows to disk. Cumulative total: 3431
# Finished processing file 19 of 2988: 5432378.csv, total rows written: 3431
#
# Processing file 20 of 2988: 5432483.csv
#   Reading phase file...
#   Phase file loaded. Shape: (1463, 138)
#     Processing chunk 1, shape before selection: (1463, 731)
#     Shape after keeping specified columns: (1463, 105)
#     Merged chunk shape: (1463, 239)
#     Written 1463 merged rows to disk. Cumulative total: 1463
# Finished processing file 20 of 2988: 5432483.csv, total rows written: 1463
#
# Processing file 21 of 2988: 5432492.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3618, 138)
#     Processing chunk 1, shape before selection: (3618, 731)
#     Shape after keeping specified columns: (3618, 105)
#     Merged chunk shape: (3618, 239)
#     Written 3618 merged rows to disk. Cumulative total: 3618
# Finished processing file 21 of 2988: 5432492.csv, total rows written: 3618
#
# Processing file 22 of 2988: 5432496.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8054, 138)
#     Processing chunk 1, shape before selection: (8054, 731)
#     Shape after keeping specified columns: (8054, 105)
#     Merged chunk shape: (8054, 239)
#     Written 8054 merged rows to disk. Cumulative total: 8054
# Finished processing file 22 of 2988: 5432496.csv, total rows written: 8054
#
# Processing file 23 of 2988: 5432677.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3603, 138)
#     Processing chunk 1, shape before selection: (3603, 731)
#     Shape after keeping specified columns: (3603, 105)
#     Merged chunk shape: (3603, 239)
#     Written 3603 merged rows to disk. Cumulative total: 3603
# Finished processing file 23 of 2988: 5432677.csv, total rows written: 3603
#
# Processing file 24 of 2988: 5432729.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3597, 138)
#     Processing chunk 1, shape before selection: (3597, 731)
#     Shape after keeping specified columns: (3597, 105)
#     Merged chunk shape: (3597, 239)
#     Written 3597 merged rows to disk. Cumulative total: 3597
# Finished processing file 24 of 2988: 5432729.csv, total rows written: 3597
#
# Processing file 25 of 2988: 5432737.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3300, 138)
#     Processing chunk 1, shape before selection: (3300, 731)
#     Shape after keeping specified columns: (3300, 105)
#     Merged chunk shape: (3300, 239)
#     Written 3300 merged rows to disk. Cumulative total: 3300
# Finished processing file 25 of 2988: 5432737.csv, total rows written: 3300
#
# Processing file 26 of 2988: 5432741.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7379, 138)
#     Processing chunk 1, shape before selection: (7379, 731)
#     Shape after keeping specified columns: (7379, 105)
#     Merged chunk shape: (7379, 239)
#     Written 7379 merged rows to disk. Cumulative total: 7379
# Finished processing file 26 of 2988: 5432741.csv, total rows written: 7379
#
# Processing file 27 of 2988: 5432795.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3480, 138)
#     Processing chunk 1, shape before selection: (3480, 731)
#     Shape after keeping specified columns: (3480, 105)
#     Merged chunk shape: (3480, 239)
#     Written 3480 merged rows to disk. Cumulative total: 3480
# Finished processing file 27 of 2988: 5432795.csv, total rows written: 3480
#
# Processing file 28 of 2988: 5432798.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3417, 138)
#     Processing chunk 1, shape before selection: (3417, 731)
#     Shape after keeping specified columns: (3417, 105)
#     Merged chunk shape: (3417, 239)
#     Written 3417 merged rows to disk. Cumulative total: 3417
# Finished processing file 28 of 2988: 5432798.csv, total rows written: 3417
#
# Processing file 29 of 2988: 5432915.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6212, 138)
#     Processing chunk 1, shape before selection: (6212, 731)
#     Shape after keeping specified columns: (6212, 105)
#     Merged chunk shape: (6212, 239)
#     Written 6212 merged rows to disk. Cumulative total: 6212
# Finished processing file 29 of 2988: 5432915.csv, total rows written: 6212
#
# Processing file 30 of 2988: 5432990.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3730, 138)
#     Processing chunk 1, shape before selection: (3730, 731)
#     Shape after keeping specified columns: (3730, 105)
#     Merged chunk shape: (3730, 239)
#     Written 3730 merged rows to disk. Cumulative total: 3730
# Finished processing file 30 of 2988: 5432990.csv, total rows written: 3730
#
# Processing file 31 of 2988: 5433037.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3092, 138)
#     Processing chunk 1, shape before selection: (3092, 731)
#     Shape after keeping specified columns: (3092, 105)
#     Merged chunk shape: (3092, 239)
#     Written 3092 merged rows to disk. Cumulative total: 3092
# Finished processing file 31 of 2988: 5433037.csv, total rows written: 3092
#
# Processing file 32 of 2988: 5433113.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4737, 138)
#     Processing chunk 1, shape before selection: (4737, 731)
#     Shape after keeping specified columns: (4737, 105)
#     Merged chunk shape: (4737, 239)
#     Written 4737 merged rows to disk. Cumulative total: 4737
# Finished processing file 32 of 2988: 5433113.csv, total rows written: 4737
#
# Processing file 33 of 2988: 5433137.csv
#   Reading phase file...
#   Phase file loaded. Shape: (14272, 138)
#     Processing chunk 1, shape before selection: (14272, 731)
#     Shape after keeping specified columns: (14272, 105)
#     Merged chunk shape: (57088, 239)
#     Written 57088 merged rows to disk. Cumulative total: 57088
# Finished processing file 33 of 2988: 5433137.csv, total rows written: 57088
#
# Processing file 34 of 2988: 5433138.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5578, 138)
#     Processing chunk 1, shape before selection: (5578, 731)
#     Shape after keeping specified columns: (5578, 105)
#     Merged chunk shape: (5578, 239)
#     Written 5578 merged rows to disk. Cumulative total: 5578
# Finished processing file 34 of 2988: 5433138.csv, total rows written: 5578
#
# Processing file 35 of 2988: 5433139.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3851, 138)
#     Processing chunk 1, shape before selection: (3851, 731)
#     Shape after keeping specified columns: (3851, 105)
#     Merged chunk shape: (3851, 239)
#     Written 3851 merged rows to disk. Cumulative total: 3851
# Finished processing file 35 of 2988: 5433139.csv, total rows written: 3851
#
# Processing file 36 of 2988: 5433143.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3144, 138)
#     Processing chunk 1, shape before selection: (3144, 731)
#     Shape after keeping specified columns: (3144, 105)
#     Merged chunk shape: (3144, 239)
#     Written 3144 merged rows to disk. Cumulative total: 3144
# Finished processing file 36 of 2988: 5433143.csv, total rows written: 3144
#
# Processing file 37 of 2988: 5433148.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3309, 138)
#     Processing chunk 1, shape before selection: (3309, 731)
#     Shape after keeping specified columns: (3309, 105)
#     Merged chunk shape: (3309, 239)
#     Written 3309 merged rows to disk. Cumulative total: 3309
# Finished processing file 37 of 2988: 5433148.csv, total rows written: 3309
#
# Processing file 38 of 2988: 5433154.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2518, 138)
#     Processing chunk 1, shape before selection: (2518, 731)
#     Shape after keeping specified columns: (2518, 105)
#     Merged chunk shape: (2518, 239)
#     Written 2518 merged rows to disk. Cumulative total: 2518
# Finished processing file 38 of 2988: 5433154.csv, total rows written: 2518
#
# Processing file 39 of 2988: 5433186.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8129, 138)
#     Processing chunk 1, shape before selection: (8129, 731)
#     Shape after keeping specified columns: (8129, 105)
#     Merged chunk shape: (8129, 239)
#     Written 8129 merged rows to disk. Cumulative total: 8129
# Finished processing file 39 of 2988: 5433186.csv, total rows written: 8129
#
# Processing file 40 of 2988: 5433261.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4620, 138)
#     Processing chunk 1, shape before selection: (4620, 731)
#     Shape after keeping specified columns: (4620, 105)
#     Merged chunk shape: (4620, 239)
#     Written 4620 merged rows to disk. Cumulative total: 4620
# Finished processing file 40 of 2988: 5433261.csv, total rows written: 4620
#
# Processing file 41 of 2988: 5433268.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3023, 138)
#     Processing chunk 1, shape before selection: (3023, 731)
#     Shape after keeping specified columns: (3023, 105)
#     Merged chunk shape: (3023, 239)
#     Written 3023 merged rows to disk. Cumulative total: 3023
# Finished processing file 41 of 2988: 5433268.csv, total rows written: 3023
#
# Processing file 42 of 2988: 5433274.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2970, 138)
#     Processing chunk 1, shape before selection: (2970, 731)
#     Shape after keeping specified columns: (2970, 105)
#     Merged chunk shape: (2970, 239)
#     Written 2970 merged rows to disk. Cumulative total: 2970
# Finished processing file 42 of 2988: 5433274.csv, total rows written: 2970
#
# Processing file 43 of 2988: 5433278.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2709, 138)
#     Processing chunk 1, shape before selection: (2709, 731)
#     Shape after keeping specified columns: (2709, 105)
#     Merged chunk shape: (2709, 239)
#     Written 2709 merged rows to disk. Cumulative total: 2709
# Finished processing file 43 of 2988: 5433278.csv, total rows written: 2709
#
# Processing file 44 of 2988: 5433284.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2495, 138)
#     Processing chunk 1, shape before selection: (2495, 731)
#     Shape after keeping specified columns: (2495, 105)
#     Merged chunk shape: (2495, 239)
#     Written 2495 merged rows to disk. Cumulative total: 2495
# Finished processing file 44 of 2988: 5433284.csv, total rows written: 2495
#
# Processing file 45 of 2988: 5433289.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2804, 138)
#     Processing chunk 1, shape before selection: (2804, 731)
#     Shape after keeping specified columns: (2804, 105)
#     Merged chunk shape: (2804, 239)
#     Written 2804 merged rows to disk. Cumulative total: 2804
# Finished processing file 45 of 2988: 5433289.csv, total rows written: 2804
#
# Processing file 46 of 2988: 5433298.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2770, 138)
#     Processing chunk 1, shape before selection: (2770, 731)
#     Shape after keeping specified columns: (2770, 105)
#     Merged chunk shape: (2770, 239)
#     Written 2770 merged rows to disk. Cumulative total: 2770
# Finished processing file 46 of 2988: 5433298.csv, total rows written: 2770
#
# Processing file 47 of 2988: 5433302.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2588, 138)
#     Processing chunk 1, shape before selection: (2588, 731)
#     Shape after keeping specified columns: (2588, 105)
#     Merged chunk shape: (2588, 239)
#     Written 2588 merged rows to disk. Cumulative total: 2588
# Finished processing file 47 of 2988: 5433302.csv, total rows written: 2588
#
# Processing file 48 of 2988: 5433341.csv
#   Reading phase file...
#   Phase file loaded. Shape: (15120, 138)
#     Processing chunk 1, shape before selection: (15120, 731)
#     Shape after keeping specified columns: (15120, 105)
#     Merged chunk shape: (60480, 239)
#     Written 60480 merged rows to disk. Cumulative total: 60480
# Finished processing file 48 of 2988: 5433341.csv, total rows written: 60480
#
# Processing file 49 of 2988: 5433344.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3781, 138)
#     Processing chunk 1, shape before selection: (3781, 731)
#     Shape after keeping specified columns: (3781, 105)
#     Merged chunk shape: (3781, 239)
#     Written 3781 merged rows to disk. Cumulative total: 3781
# Finished processing file 49 of 2988: 5433344.csv, total rows written: 3781
#
# Processing file 50 of 2988: 5433353.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3767, 138)
#     Processing chunk 1, shape before selection: (3767, 731)
#     Shape after keeping specified columns: (3767, 105)
#     Merged chunk shape: (3767, 239)
#     Written 3767 merged rows to disk. Cumulative total: 3767
# Finished processing file 50 of 2988: 5433353.csv, total rows written: 3767
#
# Processing file 51 of 2988: 5433358.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3718, 138)
#     Processing chunk 1, shape before selection: (3718, 731)
#     Shape after keeping specified columns: (3718, 105)
#     Merged chunk shape: (3718, 239)
#     Written 3718 merged rows to disk. Cumulative total: 3718
# Finished processing file 51 of 2988: 5433358.csv, total rows written: 3718
#
# Processing file 52 of 2988: 5433535.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7465, 138)
#     Processing chunk 1, shape before selection: (7465, 731)
#     Shape after keeping specified columns: (7465, 105)
#     Merged chunk shape: (7465, 239)
#     Written 7465 merged rows to disk. Cumulative total: 7465
# Finished processing file 52 of 2988: 5433535.csv, total rows written: 7465
#
# Processing file 53 of 2988: 5433540.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4104, 138)
#     Processing chunk 1, shape before selection: (4104, 731)
#     Shape after keeping specified columns: (4104, 105)
#     Merged chunk shape: (4104, 239)
#     Written 4104 merged rows to disk. Cumulative total: 4104
# Finished processing file 53 of 2988: 5433540.csv, total rows written: 4104
#
# Processing file 54 of 2988: 5433602.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3044, 138)
#     Processing chunk 1, shape before selection: (3044, 731)
#     Shape after keeping specified columns: (3044, 105)
#     Merged chunk shape: (3044, 239)
#     Written 3044 merged rows to disk. Cumulative total: 3044
# Finished processing file 54 of 2988: 5433602.csv, total rows written: 3044
#
# Processing file 55 of 2988: 5433610.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3034, 138)
#     Processing chunk 1, shape before selection: (3034, 731)
#     Shape after keeping specified columns: (3034, 105)
#     Merged chunk shape: (3034, 239)
#     Written 3034 merged rows to disk. Cumulative total: 3034
# Finished processing file 55 of 2988: 5433610.csv, total rows written: 3034
#
# Processing file 56 of 2988: 5433616.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3051, 138)
#     Processing chunk 1, shape before selection: (3051, 731)
#     Shape after keeping specified columns: (3051, 105)
#     Merged chunk shape: (3051, 239)
#     Written 3051 merged rows to disk. Cumulative total: 3051
# Finished processing file 56 of 2988: 5433616.csv, total rows written: 3051
#
# Processing file 57 of 2988: 5433736.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2833, 138)
#     Processing chunk 1, shape before selection: (2833, 731)
#     Shape after keeping specified columns: (2833, 105)
#     Merged chunk shape: (2833, 239)
#     Written 2833 merged rows to disk. Cumulative total: 2833
# Finished processing file 57 of 2988: 5433736.csv, total rows written: 2833
#
# Processing file 58 of 2988: 5433794.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4669, 138)
#     Processing chunk 1, shape before selection: (4669, 731)
#     Shape after keeping specified columns: (4669, 105)
#     Merged chunk shape: (4669, 239)
#     Written 4669 merged rows to disk. Cumulative total: 4669
# Finished processing file 58 of 2988: 5433794.csv, total rows written: 4669
#
# Processing file 59 of 2988: 5433804.csv
#   Reading phase file...
#   Phase file loaded. Shape: (9528, 138)
#     Processing chunk 1, shape before selection: (9528, 731)
#     Shape after keeping specified columns: (9528, 105)
#     Merged chunk shape: (9528, 239)
#     Written 9528 merged rows to disk. Cumulative total: 9528
# Finished processing file 59 of 2988: 5433804.csv, total rows written: 9528
#
# Processing file 60 of 2988: 5433811.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4374, 138)
#     Processing chunk 1, shape before selection: (4374, 731)
#     Shape after keeping specified columns: (4374, 105)
#     Merged chunk shape: (4374, 239)
#     Written 4374 merged rows to disk. Cumulative total: 4374
# Finished processing file 60 of 2988: 5433811.csv, total rows written: 4374
#
# Processing file 61 of 2988: 5433836.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5951, 138)
#     Processing chunk 1, shape before selection: (5951, 731)
#     Shape after keeping specified columns: (5951, 105)
#     Merged chunk shape: (5951, 239)
#     Written 5951 merged rows to disk. Cumulative total: 5951
# Finished processing file 61 of 2988: 5433836.csv, total rows written: 5951
#
# Processing file 62 of 2988: 5433844.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4638, 138)
#     Processing chunk 1, shape before selection: (4638, 731)
#     Shape after keeping specified columns: (4638, 105)
#     Merged chunk shape: (4638, 239)
#     Written 4638 merged rows to disk. Cumulative total: 4638
# Finished processing file 62 of 2988: 5433844.csv, total rows written: 4638
#
# Processing file 63 of 2988: 5433915.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3769, 138)
#     Processing chunk 1, shape before selection: (3769, 731)
#     Shape after keeping specified columns: (3769, 105)
#     Merged chunk shape: (3769, 239)
#     Written 3769 merged rows to disk. Cumulative total: 3769
# Finished processing file 63 of 2988: 5433915.csv, total rows written: 3769
#
# Processing file 64 of 2988: 5433923.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8384, 138)
#     Processing chunk 1, shape before selection: (8384, 731)
#     Shape after keeping specified columns: (8384, 105)
#     Merged chunk shape: (8384, 239)
#     Written 8384 merged rows to disk. Cumulative total: 8384
# Finished processing file 64 of 2988: 5433923.csv, total rows written: 8384
#
# Processing file 65 of 2988: 5433927.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8273, 138)
#     Processing chunk 1, shape before selection: (8273, 731)
#     Shape after keeping specified columns: (8273, 105)
#     Merged chunk shape: (8273, 239)
#     Written 8273 merged rows to disk. Cumulative total: 8273
# Finished processing file 65 of 2988: 5433927.csv, total rows written: 8273
#
# Processing file 66 of 2988: 5433947.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4630, 138)
#     Processing chunk 1, shape before selection: (4630, 731)
#     Shape after keeping specified columns: (4630, 105)
#     Merged chunk shape: (4630, 239)
#     Written 4630 merged rows to disk. Cumulative total: 4630
# Finished processing file 66 of 2988: 5433947.csv, total rows written: 4630
#
# Processing file 67 of 2988: 5433961.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3932, 138)
#     Processing chunk 1, shape before selection: (3932, 731)
#     Shape after keeping specified columns: (3932, 105)
#     Merged chunk shape: (3932, 239)
#     Written 3932 merged rows to disk. Cumulative total: 3932
# Finished processing file 67 of 2988: 5433961.csv, total rows written: 3932
#
# Processing file 68 of 2988: 5434034.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3885, 138)
#     Processing chunk 1, shape before selection: (3885, 731)
#     Shape after keeping specified columns: (3885, 105)
#     Merged chunk shape: (3885, 239)
#     Written 3885 merged rows to disk. Cumulative total: 3885
# Finished processing file 68 of 2988: 5434034.csv, total rows written: 3885
#
# Processing file 69 of 2988: 5434048.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3412, 138)
#     Processing chunk 1, shape before selection: (3412, 731)
#     Shape after keeping specified columns: (3412, 105)
#     Merged chunk shape: (3412, 239)
#     Written 3412 merged rows to disk. Cumulative total: 3412
# Finished processing file 69 of 2988: 5434048.csv, total rows written: 3412
#
# Processing file 70 of 2988: 5434057.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3724, 138)
#     Processing chunk 1, shape before selection: (3724, 731)
#     Shape after keeping specified columns: (3724, 105)
#     Merged chunk shape: (3724, 239)
#     Written 3724 merged rows to disk. Cumulative total: 3724
# Finished processing file 70 of 2988: 5434057.csv, total rows written: 3724
#
# Processing file 71 of 2988: 5434062.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3714, 138)
#     Processing chunk 1, shape before selection: (3714, 731)
#     Shape after keeping specified columns: (3714, 105)
#     Merged chunk shape: (3714, 239)
#     Written 3714 merged rows to disk. Cumulative total: 3714
# Finished processing file 71 of 2988: 5434062.csv, total rows written: 3714
#
# Processing file 72 of 2988: 5434066.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3261, 138)
#     Processing chunk 1, shape before selection: (3261, 731)
#     Shape after keeping specified columns: (3261, 105)
#     Merged chunk shape: (3261, 239)
#     Written 3261 merged rows to disk. Cumulative total: 3261
# Finished processing file 72 of 2988: 5434066.csv, total rows written: 3261
#
# Processing file 73 of 2988: 5434074.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2786, 138)
#     Processing chunk 1, shape before selection: (2786, 731)
#     Shape after keeping specified columns: (2786, 105)
#     Merged chunk shape: (2786, 239)
#     Written 2786 merged rows to disk. Cumulative total: 2786
# Finished processing file 73 of 2988: 5434074.csv, total rows written: 2786
#
# Processing file 74 of 2988: 5434081.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5484, 138)
#     Processing chunk 1, shape before selection: (5484, 731)
#     Shape after keeping specified columns: (5484, 105)
#     Merged chunk shape: (5484, 239)
#     Written 5484 merged rows to disk. Cumulative total: 5484
# Finished processing file 74 of 2988: 5434081.csv, total rows written: 5484
#
# Processing file 75 of 2988: 5434094.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2424, 138)
#     Processing chunk 1, shape before selection: (2424, 731)
#     Shape after keeping specified columns: (2424, 105)
#     Merged chunk shape: (2424, 239)
#     Written 2424 merged rows to disk. Cumulative total: 2424
# Finished processing file 75 of 2988: 5434094.csv, total rows written: 2424
#
# Processing file 76 of 2988: 5434099.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2900, 138)
#     Processing chunk 1, shape before selection: (2900, 731)
#     Shape after keeping specified columns: (2900, 105)
#     Merged chunk shape: (2900, 239)
#     Written 2900 merged rows to disk. Cumulative total: 2900
# Finished processing file 76 of 2988: 5434099.csv, total rows written: 2900
#
# Processing file 77 of 2988: 5434106.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6869, 138)
#     Processing chunk 1, shape before selection: (6869, 731)
#     Shape after keeping specified columns: (6869, 105)
#     Merged chunk shape: (6869, 239)
#     Written 6869 merged rows to disk. Cumulative total: 6869
# Finished processing file 77 of 2988: 5434106.csv, total rows written: 6869
#
# Processing file 78 of 2988: 5434200.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2794, 138)
#     Processing chunk 1, shape before selection: (2794, 731)
#     Shape after keeping specified columns: (2794, 105)
#     Merged chunk shape: (2794, 239)
#     Written 2794 merged rows to disk. Cumulative total: 2794
# Finished processing file 78 of 2988: 5434200.csv, total rows written: 2794
#
# Processing file 79 of 2988: 5434203.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2749, 138)
#     Processing chunk 1, shape before selection: (2749, 731)
#     Shape after keeping specified columns: (2749, 105)
#     Merged chunk shape: (2749, 239)
#     Written 2749 merged rows to disk. Cumulative total: 2749
# Finished processing file 79 of 2988: 5434203.csv, total rows written: 2749
#
# Processing file 80 of 2988: 5434208.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2846, 138)
#     Processing chunk 1, shape before selection: (2846, 731)
#     Shape after keeping specified columns: (2846, 105)
#     Merged chunk shape: (2846, 239)
#     Written 2846 merged rows to disk. Cumulative total: 2846
# Finished processing file 80 of 2988: 5434208.csv, total rows written: 2846
#
# Processing file 81 of 2988: 5434212.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2810, 138)
#     Processing chunk 1, shape before selection: (2810, 731)
#     Shape after keeping specified columns: (2810, 105)
#     Merged chunk shape: (2810, 239)
#     Written 2810 merged rows to disk. Cumulative total: 2810
# Finished processing file 81 of 2988: 5434212.csv, total rows written: 2810
#
# Processing file 82 of 2988: 5434217.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2822, 138)
#     Processing chunk 1, shape before selection: (2822, 731)
#     Shape after keeping specified columns: (2822, 105)
#     Merged chunk shape: (2822, 239)
#     Written 2822 merged rows to disk. Cumulative total: 2822
# Finished processing file 82 of 2988: 5434217.csv, total rows written: 2822
#
# Processing file 83 of 2988: 5434221.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2826, 138)
#     Processing chunk 1, shape before selection: (2826, 731)
#     Shape after keeping specified columns: (2826, 105)
#     Merged chunk shape: (2826, 239)
#     Written 2826 merged rows to disk. Cumulative total: 2826
# Finished processing file 83 of 2988: 5434221.csv, total rows written: 2826
#
# Processing file 84 of 2988: 5434228.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6015, 138)
#     Processing chunk 1, shape before selection: (6015, 731)
#     Shape after keeping specified columns: (6015, 105)
#     Merged chunk shape: (6015, 239)
#     Written 6015 merged rows to disk. Cumulative total: 6015
# Finished processing file 84 of 2988: 5434228.csv, total rows written: 6015
#
# Processing file 85 of 2988: 5434232.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3133, 138)
#     Processing chunk 1, shape before selection: (3133, 731)
#     Shape after keeping specified columns: (3133, 105)
#     Merged chunk shape: (3133, 239)
#     Written 3133 merged rows to disk. Cumulative total: 3133
# Finished processing file 85 of 2988: 5434232.csv, total rows written: 3133
#
# Processing file 86 of 2988: 5434235.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3056, 138)
#     Processing chunk 1, shape before selection: (3056, 731)
#     Shape after keeping specified columns: (3056, 105)
#     Merged chunk shape: (3056, 239)
#     Written 3056 merged rows to disk. Cumulative total: 3056
# Finished processing file 86 of 2988: 5434235.csv, total rows written: 3056
#
# Processing file 87 of 2988: 5434236.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2710, 138)
#     Processing chunk 1, shape before selection: (2710, 731)
#     Shape after keeping specified columns: (2710, 105)
#     Merged chunk shape: (2710, 239)
#     Written 2710 merged rows to disk. Cumulative total: 2710
# Finished processing file 87 of 2988: 5434236.csv, total rows written: 2710
#
# Processing file 88 of 2988: 5434240.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2718, 138)
#     Processing chunk 1, shape before selection: (2718, 731)
#     Shape after keeping specified columns: (2718, 105)
#     Merged chunk shape: (2718, 239)
#     Written 2718 merged rows to disk. Cumulative total: 2718
# Finished processing file 88 of 2988: 5434240.csv, total rows written: 2718
#
# Processing file 89 of 2988: 5434248.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2721, 138)
#     Processing chunk 1, shape before selection: (2721, 731)
#     Shape after keeping specified columns: (2721, 105)
#     Merged chunk shape: (2721, 239)
#     Written 2721 merged rows to disk. Cumulative total: 2721
# Finished processing file 89 of 2988: 5434248.csv, total rows written: 2721
#
# Processing file 90 of 2988: 5434272.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4037, 138)
#     Processing chunk 1, shape before selection: (4037, 731)
#     Shape after keeping specified columns: (4037, 105)
#     Merged chunk shape: (4037, 239)
#     Written 4037 merged rows to disk. Cumulative total: 4037
# Finished processing file 90 of 2988: 5434272.csv, total rows written: 4037
#
# Processing file 91 of 2988: 5434301.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3913, 138)
#     Processing chunk 1, shape before selection: (3913, 731)
#     Shape after keeping specified columns: (3913, 105)
#     Merged chunk shape: (3913, 239)
#     Written 3913 merged rows to disk. Cumulative total: 3913
# Finished processing file 91 of 2988: 5434301.csv, total rows written: 3913
#
# Processing file 92 of 2988: 5434304.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7559, 138)
#     Processing chunk 1, shape before selection: (7559, 731)
#     Shape after keeping specified columns: (7559, 105)
#     Merged chunk shape: (7559, 239)
#     Written 7559 merged rows to disk. Cumulative total: 7559
# Finished processing file 92 of 2988: 5434304.csv, total rows written: 7559
#
# Processing file 93 of 2988: 5434340.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3133, 138)
#     Processing chunk 1, shape before selection: (3133, 731)
#     Shape after keeping specified columns: (3133, 105)
#     Merged chunk shape: (3133, 239)
#     Written 3133 merged rows to disk. Cumulative total: 3133
# Finished processing file 93 of 2988: 5434340.csv, total rows written: 3133
#
# Processing file 94 of 2988: 5434346.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3442, 138)
#     Processing chunk 1, shape before selection: (3442, 731)
#     Shape after keeping specified columns: (3442, 105)
#     Merged chunk shape: (3442, 239)
#     Written 3442 merged rows to disk. Cumulative total: 3442
# Finished processing file 94 of 2988: 5434346.csv, total rows written: 3442
#
# Processing file 95 of 2988: 5434393.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4460, 138)
#     Processing chunk 1, shape before selection: (4460, 731)
#     Shape after keeping specified columns: (4460, 105)
#     Merged chunk shape: (4460, 239)
#     Written 4460 merged rows to disk. Cumulative total: 4460
# Finished processing file 95 of 2988: 5434393.csv, total rows written: 4460
#
# Processing file 96 of 2988: 5434419.csv
#   Reading phase file...
#   Phase file loaded. Shape: (259, 138)
#     Processing chunk 1, shape before selection: (259, 731)
#     Shape after keeping specified columns: (259, 105)
#     Merged chunk shape: (259, 239)
#     Written 259 merged rows to disk. Cumulative total: 259
# Finished processing file 96 of 2988: 5434419.csv, total rows written: 259
#
# Processing file 97 of 2988: 5434422.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3785, 138)
#     Processing chunk 1, shape before selection: (3785, 731)
#     Shape after keeping specified columns: (3785, 105)
#     Merged chunk shape: (3785, 239)
#     Written 3785 merged rows to disk. Cumulative total: 3785
# Finished processing file 97 of 2988: 5434422.csv, total rows written: 3785
#
# Processing file 98 of 2988: 5434426.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6280, 138)
#     Processing chunk 1, shape before selection: (6280, 731)
#     Shape after keeping specified columns: (6280, 105)
#     Merged chunk shape: (6280, 239)
#     Written 6280 merged rows to disk. Cumulative total: 6280
# Finished processing file 98 of 2988: 5434426.csv, total rows written: 6280
#
# Processing file 99 of 2988: 5434471.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3766, 138)
#     Processing chunk 1, shape before selection: (3766, 731)
#     Shape after keeping specified columns: (3766, 105)
#     Merged chunk shape: (3766, 239)
#     Written 3766 merged rows to disk. Cumulative total: 3766
# Finished processing file 99 of 2988: 5434471.csv, total rows written: 3766
#
# Processing file 100 of 2988: 5434476.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7469, 138)
#     Processing chunk 1, shape before selection: (7469, 731)
#     Shape after keeping specified columns: (7469, 105)
#     Merged chunk shape: (7469, 239)
#     Written 7469 merged rows to disk. Cumulative total: 7469
# Finished processing file 100 of 2988: 5434476.csv, total rows written: 7469
#
# Processing file 101 of 2988: 5434488.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6150, 138)
#     Processing chunk 1, shape before selection: (6150, 731)
#     Shape after keeping specified columns: (6150, 105)
#     Merged chunk shape: (6150, 239)
#     Written 6150 merged rows to disk. Cumulative total: 6150
# Finished processing file 101 of 2988: 5434488.csv, total rows written: 6150
#
# Processing file 102 of 2988: 5434569.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3114, 138)
#     Processing chunk 1, shape before selection: (3114, 731)
#     Shape after keeping specified columns: (3114, 105)
#     Merged chunk shape: (3114, 239)
#     Written 3114 merged rows to disk. Cumulative total: 3114
# Finished processing file 102 of 2988: 5434569.csv, total rows written: 3114
#
# Processing file 103 of 2988: 5434586.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3676, 138)
#     Processing chunk 1, shape before selection: (3676, 731)
#     Shape after keeping specified columns: (3676, 105)
#     Merged chunk shape: (3676, 239)
#     Written 3676 merged rows to disk. Cumulative total: 3676
# Finished processing file 103 of 2988: 5434586.csv, total rows written: 3676
#
# Processing file 104 of 2988: 5434592.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3489, 138)
#     Processing chunk 1, shape before selection: (3489, 731)
#     Shape after keeping specified columns: (3489, 105)
#     Merged chunk shape: (3489, 239)
#     Written 3489 merged rows to disk. Cumulative total: 3489
# Finished processing file 104 of 2988: 5434592.csv, total rows written: 3489
#
# Processing file 105 of 2988: 5434603.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3820, 138)
#     Processing chunk 1, shape before selection: (3820, 731)
#     Shape after keeping specified columns: (3820, 105)
#     Merged chunk shape: (3820, 239)
#     Written 3820 merged rows to disk. Cumulative total: 3820
# Finished processing file 105 of 2988: 5434603.csv, total rows written: 3820
#
# Processing file 106 of 2988: 5434617.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3117, 138)
#     Processing chunk 1, shape before selection: (3117, 731)
#     Shape after keeping specified columns: (3117, 105)
#     Merged chunk shape: (3117, 239)
#     Written 3117 merged rows to disk. Cumulative total: 3117
# Finished processing file 106 of 2988: 5434617.csv, total rows written: 3117
#
# Processing file 107 of 2988: 5434628.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3506, 138)
#     Processing chunk 1, shape before selection: (3506, 731)
#     Shape after keeping specified columns: (3506, 105)
#     Merged chunk shape: (3506, 239)
#     Written 3506 merged rows to disk. Cumulative total: 3506
# Finished processing file 107 of 2988: 5434628.csv, total rows written: 3506
#
# Processing file 108 of 2988: 5434636.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6063, 138)
#     Processing chunk 1, shape before selection: (6063, 731)
#     Shape after keeping specified columns: (6063, 105)
#     Merged chunk shape: (6063, 239)
#     Written 6063 merged rows to disk. Cumulative total: 6063
# Finished processing file 108 of 2988: 5434636.csv, total rows written: 6063
#
# Processing file 109 of 2988: 5434642.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6615, 138)
#     Processing chunk 1, shape before selection: (6615, 731)
#     Shape after keeping specified columns: (6615, 105)
#     Merged chunk shape: (6615, 239)
#     Written 6615 merged rows to disk. Cumulative total: 6615
# Finished processing file 109 of 2988: 5434642.csv, total rows written: 6615
#
# Processing file 110 of 2988: 5434645.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3871, 138)
#     Processing chunk 1, shape before selection: (3871, 731)
#     Shape after keeping specified columns: (3871, 105)
#     Merged chunk shape: (3871, 239)
#     Written 3871 merged rows to disk. Cumulative total: 3871
# Finished processing file 110 of 2988: 5434645.csv, total rows written: 3871
#
# Processing file 111 of 2988: 5434650.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3618, 138)
#     Processing chunk 1, shape before selection: (3618, 731)
#     Shape after keeping specified columns: (3618, 105)
#     Merged chunk shape: (3618, 239)
#     Written 3618 merged rows to disk. Cumulative total: 3618
# Finished processing file 111 of 2988: 5434650.csv, total rows written: 3618
#
# Processing file 112 of 2988: 5434855.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4037, 138)
#     Processing chunk 1, shape before selection: (4037, 731)
#     Shape after keeping specified columns: (4037, 105)
#     Merged chunk shape: (4037, 239)
#     Written 4037 merged rows to disk. Cumulative total: 4037
# Finished processing file 112 of 2988: 5434855.csv, total rows written: 4037
#
# Processing file 113 of 2988: 5434863.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6237, 138)
#     Processing chunk 1, shape before selection: (6237, 731)
#     Shape after keeping specified columns: (6237, 105)
#     Merged chunk shape: (6237, 239)
#     Written 6237 merged rows to disk. Cumulative total: 6237
# Finished processing file 113 of 2988: 5434863.csv, total rows written: 6237
#
# Processing file 114 of 2988: 5434899.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8931, 138)
#     Processing chunk 1, shape before selection: (8931, 731)
#     Shape after keeping specified columns: (8931, 105)
#     Merged chunk shape: (8931, 239)
#     Written 8931 merged rows to disk. Cumulative total: 8931
# Finished processing file 114 of 2988: 5434899.csv, total rows written: 8931
#
# Processing file 115 of 2988: 5434902.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7154, 138)
#     Processing chunk 1, shape before selection: (7154, 731)
#     Shape after keeping specified columns: (7154, 105)
#     Merged chunk shape: (18590, 239)
#     Written 18590 merged rows to disk. Cumulative total: 18590
# Finished processing file 115 of 2988: 5434902.csv, total rows written: 18590
#
# Processing file 116 of 2988: 5434909.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3066, 138)
#     Processing chunk 1, shape before selection: (3066, 731)
#     Shape after keeping specified columns: (3066, 105)
#     Merged chunk shape: (3066, 239)
#     Written 3066 merged rows to disk. Cumulative total: 3066
# Finished processing file 116 of 2988: 5434909.csv, total rows written: 3066
#
# Processing file 117 of 2988: 5434989.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4551, 138)
#     Processing chunk 1, shape before selection: (4551, 731)
#     Shape after keeping specified columns: (4551, 105)
#     Merged chunk shape: (4551, 239)
#     Written 4551 merged rows to disk. Cumulative total: 4551
# Finished processing file 117 of 2988: 5434989.csv, total rows written: 4551
#
# Processing file 118 of 2988: 5435015.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3990, 138)
#     Processing chunk 1, shape before selection: (3990, 731)
#     Shape after keeping specified columns: (3990, 105)
#     Merged chunk shape: (3990, 239)
#     Written 3990 merged rows to disk. Cumulative total: 3990
# Finished processing file 118 of 2988: 5435015.csv, total rows written: 3990
#
# Processing file 119 of 2988: 5435017.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3317, 138)
#     Processing chunk 1, shape before selection: (3317, 731)
#     Shape after keeping specified columns: (3317, 105)
#     Merged chunk shape: (3317, 239)
#     Written 3317 merged rows to disk. Cumulative total: 3317
# Finished processing file 119 of 2988: 5435017.csv, total rows written: 3317
#
# Processing file 120 of 2988: 5435023.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4332, 138)
#     Processing chunk 1, shape before selection: (4332, 731)
#     Shape after keeping specified columns: (4332, 105)
#     Merged chunk shape: (4332, 239)
#     Written 4332 merged rows to disk. Cumulative total: 4332
# Finished processing file 120 of 2988: 5435023.csv, total rows written: 4332
#
# Processing file 121 of 2988: 5435032.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3657, 138)
#     Processing chunk 1, shape before selection: (3657, 731)
#     Shape after keeping specified columns: (3657, 105)
#     Merged chunk shape: (3657, 239)
#     Written 3657 merged rows to disk. Cumulative total: 3657
# Finished processing file 121 of 2988: 5435032.csv, total rows written: 3657
#
# Processing file 122 of 2988: 5435033.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4437, 138)
#     Processing chunk 1, shape before selection: (4437, 731)
#     Shape after keeping specified columns: (4437, 105)
#     Merged chunk shape: (4437, 239)
#     Written 4437 merged rows to disk. Cumulative total: 4437
# Finished processing file 122 of 2988: 5435033.csv, total rows written: 4437
#
# Processing file 123 of 2988: 5435037.csv
#   Reading phase file...
#   Phase file loaded. Shape: (2780, 138)
# ...
# Finished processing file 2948 of 2988: 5515596.csv, total rows written: 4646
#
# Processing file 2949 of 2988: 5515599.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8856, 138)
#     Processing chunk 1, shape before selection: (8856, 731)
#     Shape after keeping specified columns: (8856, 105)
#     Merged chunk shape: (8856, 239)
#     Written 8856 merged rows to disk. Cumulative total: 8856
# Finished processing file 2949 of 2988: 5515599.csv, total rows written: 8856
#
# Processing file 2950 of 2988: 5515646.csv
#   Reading phase file...
#   Phase file loaded. Shape: (11126, 138)
#     Processing chunk 1, shape before selection: (11126, 731)
#     Shape after keeping specified columns: (11126, 105)
#     Merged chunk shape: (11126, 239)
#     Written 11126 merged rows to disk. Cumulative total: 11126
# Finished processing file 2950 of 2988: 5515646.csv, total rows written: 11126
#
# Processing file 2951 of 2988: 5515683.csv
#   Reading phase file...
#   Phase file loaded. Shape: (7243, 138)
#     Processing chunk 1, shape before selection: (7243, 731)
#     Shape after keeping specified columns: (7243, 105)
#     Merged chunk shape: (7243, 239)
#     Written 7243 merged rows to disk. Cumulative total: 7243
# Finished processing file 2951 of 2988: 5515683.csv, total rows written: 7243
#
# Processing file 2952 of 2988: 5515686.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4283, 138)
#     Processing chunk 1, shape before selection: (4283, 731)
#     Shape after keeping specified columns: (4283, 105)
#     Merged chunk shape: (4283, 239)
#     Written 4283 merged rows to disk. Cumulative total: 4283
# Finished processing file 2952 of 2988: 5515686.csv, total rows written: 4283
#
# Processing file 2953 of 2988: 5515933.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4372, 138)
#     Processing chunk 1, shape before selection: (4372, 731)
#     Shape after keeping specified columns: (4372, 105)
#     Merged chunk shape: (4372, 239)
#     Written 4372 merged rows to disk. Cumulative total: 4372
# Finished processing file 2953 of 2988: 5515933.csv, total rows written: 4372
#
# Processing file 2954 of 2988: 5515934.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4354, 138)
#     Processing chunk 1, shape before selection: (4354, 731)
#     Shape after keeping specified columns: (4354, 105)
#     Merged chunk shape: (4354, 239)
#     Written 4354 merged rows to disk. Cumulative total: 4354
# Finished processing file 2954 of 2988: 5515934.csv, total rows written: 4354
#
# Processing file 2955 of 2988: 5515961.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4615, 138)
#     Processing chunk 1, shape before selection: (4615, 731)
#     Shape after keeping specified columns: (4615, 105)
#     Merged chunk shape: (4615, 239)
#     Written 4615 merged rows to disk. Cumulative total: 4615
# Finished processing file 2955 of 2988: 5515961.csv, total rows written: 4615
#
# Processing file 2956 of 2988: 5516013.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3226, 138)
#     Processing chunk 1, shape before selection: (3226, 731)
#     Shape after keeping specified columns: (3226, 105)
#     Merged chunk shape: (3226, 239)
#     Written 3226 merged rows to disk. Cumulative total: 3226
# Finished processing file 2956 of 2988: 5516013.csv, total rows written: 3226
#
# Processing file 2957 of 2988: 5516081.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4603, 138)
#     Processing chunk 1, shape before selection: (4603, 731)
#     Shape after keeping specified columns: (4603, 105)
#     Merged chunk shape: (4603, 239)
#     Written 4603 merged rows to disk. Cumulative total: 4603
# Finished processing file 2957 of 2988: 5516081.csv, total rows written: 4603
#
# Processing file 2958 of 2988: 5516084.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4386, 138)
#     Processing chunk 1, shape before selection: (4386, 731)
#     Shape after keeping specified columns: (4386, 105)
#     Merged chunk shape: (4386, 239)
#     Written 4386 merged rows to disk. Cumulative total: 4386
# Finished processing file 2958 of 2988: 5516084.csv, total rows written: 4386
#
# Processing file 2959 of 2988: 5516088.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5315, 138)
#     Processing chunk 1, shape before selection: (5315, 731)
#     Shape after keeping specified columns: (5315, 105)
#     Merged chunk shape: (5315, 239)
#     Written 5315 merged rows to disk. Cumulative total: 5315
# Finished processing file 2959 of 2988: 5516088.csv, total rows written: 5315
#
# Processing file 2960 of 2988: 5516106.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5465, 138)
#     Processing chunk 1, shape before selection: (5465, 731)
#     Shape after keeping specified columns: (5465, 105)
#     Merged chunk shape: (5465, 239)
#     Written 5465 merged rows to disk. Cumulative total: 5465
# Finished processing file 2960 of 2988: 5516106.csv, total rows written: 5465
#
# Processing file 2961 of 2988: 5516142.csv
#   Reading phase file...
#   Phase file loaded. Shape: (19228, 138)
#     Processing chunk 1, shape before selection: (19228, 731)
#     Shape after keeping specified columns: (19228, 105)
#     Merged chunk shape: (76912, 239)
#     Written 76912 merged rows to disk. Cumulative total: 76912
# Finished processing file 2961 of 2988: 5516142.csv, total rows written: 76912
#
# Processing file 2962 of 2988: 5516147.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4516, 138)
#     Processing chunk 1, shape before selection: (4516, 731)
#     Shape after keeping specified columns: (4516, 105)
#     Merged chunk shape: (4516, 239)
#     Written 4516 merged rows to disk. Cumulative total: 4516
# Finished processing file 2962 of 2988: 5516147.csv, total rows written: 4516
#
# Processing file 2963 of 2988: 5516242.csv
#   Reading phase file...
#   Phase file loaded. Shape: (12650, 138)
#     Processing chunk 1, shape before selection: (12650, 731)
#     Shape after keeping specified columns: (12650, 105)
#     Merged chunk shape: (50594, 239)
#     Written 50594 merged rows to disk. Cumulative total: 50594
# Finished processing file 2963 of 2988: 5516242.csv, total rows written: 50594
#
# Processing file 2964 of 2988: 5516256.csv
#   Reading phase file...
#   Phase file loaded. Shape: (16895, 138)
#     Processing chunk 1, shape before selection: (16895, 731)
#     Shape after keeping specified columns: (16895, 105)
#     Merged chunk shape: (16895, 239)
#     Written 16895 merged rows to disk. Cumulative total: 16895
# Finished processing file 2964 of 2988: 5516256.csv, total rows written: 16895
#
# Processing file 2965 of 2988: 5516291.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6176, 138)
#     Processing chunk 1, shape before selection: (6176, 731)
#     Shape after keeping specified columns: (6176, 105)
#     Merged chunk shape: (6176, 239)
#     Written 6176 merged rows to disk. Cumulative total: 6176
# Finished processing file 2965 of 2988: 5516291.csv, total rows written: 6176
#
# Processing file 2966 of 2988: 5516301.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6995, 138)
#     Processing chunk 1, shape before selection: (6995, 731)
#     Shape after keeping specified columns: (6995, 105)
#     Merged chunk shape: (6995, 239)
#     Written 6995 merged rows to disk. Cumulative total: 6995
# Finished processing file 2966 of 2988: 5516301.csv, total rows written: 6995
#
# Processing file 2967 of 2988: 5516305.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5984, 138)
#     Processing chunk 1, shape before selection: (5984, 731)
#     Shape after keeping specified columns: (5984, 105)
#     Merged chunk shape: (5984, 239)
#     Written 5984 merged rows to disk. Cumulative total: 5984
# Finished processing file 2967 of 2988: 5516305.csv, total rows written: 5984
#
# Processing file 2968 of 2988: 5516314.csv
#   Reading phase file...
#   Phase file loaded. Shape: (12338, 138)
#     Processing chunk 1, shape before selection: (12338, 731)
#     Shape after keeping specified columns: (12338, 105)
#     Merged chunk shape: (12338, 239)
#     Written 12338 merged rows to disk. Cumulative total: 12338
# Finished processing file 2968 of 2988: 5516314.csv, total rows written: 12338
#
# Processing file 2969 of 2988: 5516329.csv
#   Reading phase file...
#   Phase file loaded. Shape: (13115, 138)
#     Processing chunk 1, shape before selection: (13115, 731)
#     Shape after keeping specified columns: (13115, 105)
#     Merged chunk shape: (13115, 239)
#     Written 13115 merged rows to disk. Cumulative total: 13115
# Finished processing file 2969 of 2988: 5516329.csv, total rows written: 13115
#
# Processing file 2970 of 2988: 5516343.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5763, 138)
#     Processing chunk 1, shape before selection: (5763, 731)
#     Shape after keeping specified columns: (5763, 105)
#     Merged chunk shape: (5763, 239)
#     Written 5763 merged rows to disk. Cumulative total: 5763
# Finished processing file 2970 of 2988: 5516343.csv, total rows written: 5763
#
# Processing file 2971 of 2988: 5516349.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6680, 138)
#     Processing chunk 1, shape before selection: (6680, 731)
#     Shape after keeping specified columns: (6680, 105)
#     Merged chunk shape: (6680, 239)
#     Written 6680 merged rows to disk. Cumulative total: 6680
# Finished processing file 2971 of 2988: 5516349.csv, total rows written: 6680
#
# Processing file 2972 of 2988: 5516352.csv
#   Reading phase file...
#   Phase file loaded. Shape: (112, 138)
#     Processing chunk 1, shape before selection: (112, 731)
#     Shape after keeping specified columns: (112, 105)
#     Merged chunk shape: (112, 239)
#     Written 112 merged rows to disk. Cumulative total: 112
# Finished processing file 2972 of 2988: 5516352.csv, total rows written: 112
#
# Processing file 2973 of 2988: 5516515.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6713, 138)
#     Processing chunk 1, shape before selection: (6713, 731)
#     Shape after keeping specified columns: (6713, 105)
#     Merged chunk shape: (6713, 239)
#     Written 6713 merged rows to disk. Cumulative total: 6713
# Finished processing file 2973 of 2988: 5516515.csv, total rows written: 6713
#
# Processing file 2974 of 2988: 5516783.csv
#   Reading phase file...
#   Phase file loaded. Shape: (8647, 138)
#     Processing chunk 1, shape before selection: (8647, 731)
#     Shape after keeping specified columns: (8647, 105)
#     Merged chunk shape: (8647, 239)
#     Written 8647 merged rows to disk. Cumulative total: 8647
# Finished processing file 2974 of 2988: 5516783.csv, total rows written: 8647
#
# Processing file 2975 of 2988: 5516787.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6223, 138)
#     Processing chunk 1, shape before selection: (6223, 731)
#     Shape after keeping specified columns: (6223, 105)
#     Merged chunk shape: (6223, 239)
#     Written 6223 merged rows to disk. Cumulative total: 6223
# Finished processing file 2975 of 2988: 5516787.csv, total rows written: 6223
#
# Processing file 2976 of 2988: 5516790.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3585, 138)
#     Processing chunk 1, shape before selection: (3585, 731)
#     Shape after keeping specified columns: (3585, 105)
#     Merged chunk shape: (3585, 239)
#     Written 3585 merged rows to disk. Cumulative total: 3585
# Finished processing file 2976 of 2988: 5516790.csv, total rows written: 3585
#
# Processing file 2977 of 2988: 5516793.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4711, 138)
#     Processing chunk 1, shape before selection: (4711, 731)
#     Shape after keeping specified columns: (4711, 105)
#     Merged chunk shape: (4711, 239)
#     Written 4711 merged rows to disk. Cumulative total: 4711
# Finished processing file 2977 of 2988: 5516793.csv, total rows written: 4711
#
# Processing file 2978 of 2988: 5516798.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4970, 138)
#     Processing chunk 1, shape before selection: (4970, 731)
#     Shape after keeping specified columns: (4970, 105)
#     Merged chunk shape: (4970, 239)
#     Written 4970 merged rows to disk. Cumulative total: 4970
# Finished processing file 2978 of 2988: 5516798.csv, total rows written: 4970
#
# Processing file 2979 of 2988: 5516937.csv
#   Reading phase file...
#   Phase file loaded. Shape: (10738, 138)
#     Processing chunk 1, shape before selection: (10738, 731)
#     Shape after keeping specified columns: (10738, 105)
#     Merged chunk shape: (10738, 239)
#     Written 10738 merged rows to disk. Cumulative total: 10738
# Finished processing file 2979 of 2988: 5516937.csv, total rows written: 10738
#
# Processing file 2980 of 2988: 5516941.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4851, 138)
#     Processing chunk 1, shape before selection: (4851, 731)
#     Shape after keeping specified columns: (4851, 105)
#     Merged chunk shape: (4851, 239)
#     Written 4851 merged rows to disk. Cumulative total: 4851
# Finished processing file 2980 of 2988: 5516941.csv, total rows written: 4851
#
# Processing file 2981 of 2988: 5516945.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4240, 138)
#     Processing chunk 1, shape before selection: (4240, 731)
#     Shape after keeping specified columns: (4240, 105)
#     Merged chunk shape: (4240, 239)
#     Written 4240 merged rows to disk. Cumulative total: 4240
# Finished processing file 2981 of 2988: 5516945.csv, total rows written: 4240
#
# Processing file 2982 of 2988: 5516948.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3971, 138)
#     Processing chunk 1, shape before selection: (3971, 731)
#     Shape after keeping specified columns: (3971, 105)
#     Merged chunk shape: (3971, 239)
#     Written 3971 merged rows to disk. Cumulative total: 3971
# Finished processing file 2982 of 2988: 5516948.csv, total rows written: 3971
#
# Processing file 2983 of 2988: 5517052.csv
#   Reading phase file...
#   Phase file loaded. Shape: (4611, 138)
#     Processing chunk 1, shape before selection: (4611, 731)
#     Shape after keeping specified columns: (4611, 105)
#     Merged chunk shape: (4611, 239)
#     Written 4611 merged rows to disk. Cumulative total: 4611
# Finished processing file 2983 of 2988: 5517052.csv, total rows written: 4611
#
# Processing file 2984 of 2988: 5517118.csv
#   Reading phase file...
#   Phase file loaded. Shape: (5012, 138)
#     Processing chunk 1, shape before selection: (5012, 731)
#     Shape after keeping specified columns: (5012, 105)
#     Merged chunk shape: (5012, 239)
#     Written 5012 merged rows to disk. Cumulative total: 5012
# Finished processing file 2984 of 2988: 5517118.csv, total rows written: 5012
#
# Processing file 2985 of 2988: 5517156.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3875, 138)
#     Processing chunk 1, shape before selection: (3875, 731)
#     Shape after keeping specified columns: (3875, 105)
#     Merged chunk shape: (3875, 239)
#     Written 3875 merged rows to disk. Cumulative total: 3875
# Finished processing file 2985 of 2988: 5517156.csv, total rows written: 3875
#
# Processing file 2986 of 2988: 5517162.csv
#   Reading phase file...
#   Phase file loaded. Shape: (6802, 138)
#     Processing chunk 1, shape before selection: (6802, 731)
#     Shape after keeping specified columns: (6802, 105)
#     Merged chunk shape: (6802, 239)
#     Written 6802 merged rows to disk. Cumulative total: 6802
# Finished processing file 2986 of 2988: 5517162.csv, total rows written: 6802
#
# Processing file 2987 of 2988: 5517572.csv
#   Reading phase file...
#   Phase file loaded. Shape: (3735, 138)
#     Processing chunk 1, shape before selection: (3735, 731)
#     Shape after keeping specified columns: (3735, 105)
#     Merged chunk shape: (3735, 239)
#     Written 3735 merged rows to disk. Cumulative total: 3735
# Finished processing file 2987 of 2988: 5517572.csv, total rows written: 3735
#
# Processing file 2988 of 2988: 5517578.csv
#   Reading phase file...
#   Phase file loaded. Shape: (19840, 138)
#     Processing chunk 1, shape before selection: (19840, 731)
#     Shape after keeping specified columns: (19840, 105)
#     Merged chunk shape: (79324, 239)
#     Written 79324 merged rows to disk. Cumulative total: 79324
# Finished processing file 2988 of 2988: 5517578.csv, total rows written: 79324
# All files processed!

# %% [markdown]
# ## Creating Sample of 50

# %%
import os
import shutil
import random
import zipfile

# Input folders
master_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Master whole Phase"       # Old IBA
phase_folder = r"D:\Stelco\Work\Dynamic Correlation\All coils remaining columns\Whole Phase"  # New IBA

# Output ZIP file paths
master_zip_path = r"D:\Stelco\Work\Dynamic Correlation\Old_IBA_50.zip"
phase_zip_path = r"D:\Stelco\Work\Dynamic Correlation\New_IBA_50.zip"

# Temp folders
temp_master = r"D:\Stelco\Work\Dynamic Correlation\Temp_Master"
temp_phase = r"D:\Stelco\Work\Dynamic Correlation\Temp_Phase"

# Create temp folders
os.makedirs(temp_master, exist_ok=True)
os.makedirs(temp_phase, exist_ok=True)

# Get matching CSV files
master_files = set(f for f in os.listdir(master_folder) if f.endswith('.csv'))
phase_files = set(f for f in os.listdir(phase_folder) if f.endswith('.csv'))
common_files = list(master_files & phase_files)

# Sample 50 filenames
sample_files = random.sample(common_files, 50)

# Copy sampled files to respective temp folders
for filename in sample_files:
    shutil.copy(os.path.join(master_folder, filename), os.path.join(temp_master, filename))
    shutil.copy(os.path.join(phase_folder, filename), os.path.join(temp_phase, filename))
