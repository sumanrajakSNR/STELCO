# %%
import os
import shutil

# List of coil id filename strings (as given, without extension)
filenames = [
    '5402387', '5432175', '5437517', '5432204', '5438030', '5435196', '5438327',
    '5435234', '5441834', '5435286', '5446021', '5435560', '5455788', '5436063',
    '5457596', '5438789', '5461234', '5453288', '5463522', '5456296', '5464522',
    '5448810', '5464927', '5463257', '5471946', '5463578', '5474571', '5471395',
    '5475119', '5475084', '5475128', '5401785', '5477604', '5402372'
]

source_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Whole_Phase_Good"
destination_folder = r"D:\Stelco\Work\Dynamic Correlation\Key\Whole Phase new"

for coil_id in filenames:
    source_file = os.path.join(source_folder, coil_id + '.csv')
    destination_file = os.path.join(destination_folder, coil_id + '.csv')
    if os.path.exists(source_file):
        shutil.copy2(source_file, destination_file)
        print(f"Copied {coil_id}.csv")
    else:
        print(f"{coil_id}.csv not found")
# Out:
# Copied 5402387.csv
# Copied 5432175.csv
# Copied 5437517.csv
# Copied 5432204.csv
# Copied 5438030.csv
# Copied 5435196.csv
# Copied 5438327.csv
# Copied 5435234.csv
# Copied 5441834.csv
# Copied 5435286.csv
# Copied 5446021.csv
# Copied 5435560.csv
# Copied 5455788.csv
# Copied 5436063.csv
# Copied 5457596.csv
# Copied 5438789.csv
# Copied 5461234.csv
# Copied 5453288.csv
# Copied 5463522.csv
# Copied 5456296.csv
# Copied 5464522.csv
# Copied 5448810.csv
# Copied 5464927.csv
# Copied 5463257.csv
# Copied 5471946.csv
# Copied 5463578.csv
# Copied 5474571.csv
# Copied 5471395.csv
# Copied 5475119.csv
# Copied 5475084.csv
# Copied 5475128.csv
# Copied 5401785.csv
# Copied 5477604.csv
# Copied 5402372.csv
