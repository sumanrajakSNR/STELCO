# %%
import pandas as pd

# %%
Phase = 3
df = pd.read_excel("Good_and_Bad_Coils_Phasewise_correlation_summary_with_comparison_15-90_Operator.xlsx",sheet_name = f'Phase {Phase} Correlated Signals')

# %%
signal_of_A = df['In Bad Coils'].dropna()

signal_of_B = df['In Good Coils'].dropna()

# %%
len(signal_of_A)
# Out:
# 26

# %%
len(signal_of_B)
# Out:
# 57

# %%
len(set(signal_of_A))
# Out:
# 26

# %%
len(set(signal_of_B))
# Out:
# 57

# %%
diff = set(signal_of_A) - set(signal_of_B)
for i in diff:
    print(i)
# Out:
# Stand 2 - Total Force
# Stand 2 Bottom Current Feedback
# X4 Gauge Deviation
# Stand 2 Top Current Feedback
# Stand 2 OS Roll Force
# Roll Force Hydraulics Pressure Feedback
# Stand 2 - Operator Side Force
# Stand 3 Top Current Feedback
